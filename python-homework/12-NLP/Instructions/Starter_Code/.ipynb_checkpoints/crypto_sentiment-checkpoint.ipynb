# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

# %%
# Read your api key environment variable
load_dotenv()
newsapi_key = os.getenv('NEWSAPI_KEY')

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=newsapi_key)

from pynytimes import NYTAPI
nyt = NYTAPI(os.getenv('NYT_KEY'))

# %%
# Fetch the Bitcoin news articles
bitcoin_articles = newsapi.get_everything(
    q='bitcoin', language='en', sort_by='relevancy', page = 1, page_size = 100
)

# %%
# Fetch the Ethereum news articles
ethereum_articles = newsapi.get_everything(
    q='ethereum', language='en', sort_by='relevancy', page = 1, page_size = 100
)

# %%
# Create the Bitcoin sentiment scores DataFrame
# Dedupe and remove articles with content = None
valid_bitcoin_articles = list(set([article['content'] for article in bitcoin_articles['articles'] if article['content'] != None]))
bitcoin_scores = [analyzer.polarity_scores(article) for article in valid_bitcoin_articles]
bitcoin_df = pd.DataFrame(
    data={
        'Compound': [score['compound'] for score in bitcoin_scores],
        'Negative': [score['neg'] for score in bitcoin_scores],
        'Neutral': [score['neu'] for score in bitcoin_scores],
        'Positive': [score['pos'] for score in bitcoin_scores],
        'text': valid_bitcoin_articles
    }
)
bitcoin_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7506     0.000    0.802     0.198
# 1   -0.5272     0.089    0.882     0.029
# 2   -0.2677     0.074    0.881     0.045
# 3    0.3818     0.000    0.933     0.067
# 4    0.3400     0.000    0.930     0.070
#
#                                                 text
# 0  FTX, a cryptocurrency exchange that offers der...
# 1  Isolation.site does just one thing: it visits ...
# 2  An outspoken Bitcoin whale who rarely shows af...
# 3  ...The canton, which bills itself as home to "...
# 4  Gold and oil have historically been reliable s...

# %%
# Create the ethereum sentiment scores DataFrame
# Dedupe and remove articles with content = None
valid_ethereum_articles = list(set([article['content'] for article in ethereum_articles['articles'] if article['content'] != None]))
ethereum_scores = [analyzer.polarity_scores(article) for article in valid_ethereum_articles]
ethereum_df = pd.DataFrame(
    data={
        'Compound': [score['compound'] for score in ethereum_scores],
        'Negative': [score['neg'] for score in ethereum_scores],
        'Neutral': [score['neu'] for score in ethereum_scores],
        'Positive': [score['pos'] for score in ethereum_scores],
        'text': valid_ethereum_articles
    }
)
ethereum_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.4019       0.0    0.924     0.076
# 1    0.6369       0.0    0.843     0.157
# 2    0.1779       0.0    0.952     0.048
# 3    0.6486       0.0    0.836     0.164
# 4    0.0644       0.0    0.965     0.035
#
#                                                 text
# 0  An Ethereum smart contract feature that offers...
# 1  Swisscom Blockchain, a distributed ledger tech...
# 2  The native token for OMG Network has more than...
# 3  The Takeaway\r\n<ul><li>Under development by t...
# 4  Uniswaps governance token, UNI, which was laun...

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  90.000000  90.000000  90.000000  90.000000
# mean    0.158027   0.044111   0.876511   0.079367
# std     0.475237   0.070495   0.086926   0.067808
# min    -0.865800   0.000000   0.588000   0.000000
# 25%     0.000000   0.000000   0.810000   0.007000
# 50%     0.272300   0.000000   0.908000   0.088000
# 75%     0.507000   0.087250   0.915000   0.108500
# max     0.923100   0.294000   1.000000   0.326000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  95.000000  95.000000  95.000000  95.000000
# mean    0.141825   0.035442   0.895000   0.069547
# std     0.402940   0.066063   0.086984   0.068289
# min    -0.910000   0.000000   0.607000   0.000000
# 25%     0.000000   0.000000   0.842000   0.000000
# 50%     0.177900   0.000000   0.909000   0.068000
# 75%     0.411700   0.063000   0.956500   0.103500
# max     0.851900   0.347000   1.000000   0.311000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?

# %%
print(f"A: {'Bitcoin' if bitcoin_df.Positive.mean() > ethereum_df.Positive.mean() else 'Ethereum'} @ {max(bitcoin_df.Positive.mean(),ethereum_df.Positive.mean())}")
# Out:
# A: Bitcoin @ 0.07936666666666664

# %% [markdown]
# Q: Which coin had the highest compound score?

# %%
print(f"A: {'Bitcoin' if bitcoin_df.Compound.mean() > ethereum_df.Compound.mean() else 'Ethereum'} @ {max(bitcoin_df.Compound.mean(),ethereum_df.Compound.mean())}")
# Out:
# A: Bitcoin @ 0.15802666666666662

# %% [markdown]
# Q. Which coin had the highest positive score?

# %%
print(f"A: {'Bitcoin' if bitcoin_df.Positive.max() > ethereum_df.Positive.max() else 'Ethereum'} @ {max(bitcoin_df.Positive.max(),ethereum_df.Positive.max())}")
# Out:
# A: Bitcoin @ 0.326

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
sw = set(stopwords.words('english'))

# %%
# Complete the tokenizer function
def tokenizer(text):
    '''Tokenizes text.'''
    
    # Create a list of the words
    text_list = text.split(' ')

    # Convert the words to lowercase
    text_list = [text.lower() for text in text_list]
    
    # Remove the stop words
    text_list = [text for text in text_list if text not in sw]
    
    # Remove the punctuation
    regex = re.compile('[^a-zA-Z]')
    text_list = [regex.sub('', text) for text in text_list]
    
    # Lemmatize Words into root words
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(text) for text in text_list if text != '']
    
    return tokens

# %%
# Create a new tokens column for bitcoin
bitcoin_df['tokens'] = bitcoin_df.text.apply(
    lambda x: tokenizer(x)
)
bitcoin_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7506     0.000    0.802     0.198
# 1   -0.5272     0.089    0.882     0.029
# 2   -0.2677     0.074    0.881     0.045
# 3    0.3818     0.000    0.933     0.067
# 4    0.3400     0.000    0.930     0.070
#
#                                                 text  \
# 0  FTX, a cryptocurrency exchange that offers der...
# 1  Isolation.site does just one thing: it visits ...
# 2  An outspoken Bitcoin whale who rarely shows af...
# 3  ...The canton, which bills itself as home to "...
# 4  Gold and oil have historically been reliable s...
#
#                                               tokens
# 0  [ftx, cryptocurrency, exchange, offer, derivat...
# 1  [isolationsite, one, thing, visit, url, want, ...
# 2  [outspoken, bitcoin, whale, rarely, show, affe...
# 3  [the, canton, bill, home, crypto, valley, said...
# 4  [gold, oil, historically, reliable, store, val...

# %%
# Create a new tokens column for ethereum
ethereum_df['tokens'] = ethereum_df.text.apply(
    lambda x: tokenizer(x)
)
ethereum_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.4019       0.0    0.924     0.076
# 1    0.6369       0.0    0.843     0.157
# 2    0.1779       0.0    0.952     0.048
# 3    0.6486       0.0    0.836     0.164
# 4    0.0644       0.0    0.965     0.035
#
#                                                 text  \
# 0  An Ethereum smart contract feature that offers...
# 1  Swisscom Blockchain, a distributed ledger tech...
# 2  The native token for OMG Network has more than...
# 3  The Takeaway\r\n<ul><li>Under development by t...
# 4  Uniswaps governance token, UNI, which was laun...
#
#                                               tokens
# 0  [ethereum, smart, contract, feature, offer, re...
# 1  [swisscom, blockchain, distributed, ledger, te...
# 2  [native, token, omg, network, doubled, past, w...
# 3  [takeawayulliunder, development, lnpbp, standa...
# 4  [uniswaps, governance, token, uni, launched, w...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
Counter(ngrams(bitcoin_df.tokens.sum(), n=2)).most_common(20)
# Out:
# [(('satoshi', 'nakaboto'), 40),
#  (('char', 'robot'), 20),
#  (('robot', 'colleague'), 20),
#  (('colleague', 'satoshi'), 20),
#  (('nakaboto', 'writes'), 20),
#  (('writes', 'bitcoin'), 20),
#  (('every', 'fucking'), 20),
#  (('fucking', 'daywelcome'), 20),
#  (('daywelcome', 'another'), 20),
#  (('another', 'edition'), 20),
#  (('edition', 'bitcoin'), 20),
#  (('bitcoin', 'today'), 20),
#  (('today', 'i'), 20),
#  (('i', 'satoshi'), 20),
#  (('nakaboto', 'tell'), 20),
#  (('tell', 'whats'), 20),
#  (('whats', 'going'), 20),
#  (('going', 'bitcoin'), 20),
#  (('bitcoin', 'char'), 20),
#  (('bitcoin', 'btc'), 17)]

# %%
# Generate the Ethereum N-grams where N=2
Counter(ngrams(ethereum_df.tokens.sum(), n=2)).most_common(20)
# Out:
# [(('decentralized', 'finance'), 10),
#  (('char', 'ethereum'), 10),
#  (('finance', 'defi'), 8),
#  (('ethereum', 'classic'), 6),
#  (('char', 'bitcoin'), 6),
#  (('ethereum', 'blockchain'), 6),
#  (('t', 'char'), 5),
#  (('around', 'utc'), 5),
#  (('ethereum', 'miner'), 5),
#  (('smart', 'contract'), 4),
#  (('btc', 'trading'), 4),
#  (('trading', 'around'), 4),
#  (('utc', 'pm'), 4),
#  (('pm', 'et'), 4),
#  (('ether', 'char'), 4),
#  (('th', 'char'), 3),
#  (('omg', 'network'), 3),
#  (('went', 'live'), 3),
#  (('critical', 'bug'), 3),
#  (('bug', 'left'), 3)]

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    '''Returns the top N tokens from the frequency count'''
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(bitcoin_df.tokens.sum())
# Out:
# [('char', 90),
#  ('bitcoin', 90),
#  ('satoshi', 40),
#  ('nakaboto', 40),
#  ('every', 22),
#  ('i', 22),
#  ('going', 22),
#  ('another', 21),
#  ('edition', 21),
#  ('robot', 20)]

# %%
# Get the top 10 words for Ethereum
token_count(ethereum_df.tokens.sum())
# Out:
# [('char', 95),
#  ('ethereum', 63),
#  ('bitcoin', 22),
#  ('blockchain', 20),
#  ('cryptocurrency', 15),
#  ('decentralized', 15),
#  ('defi', 15),
#  ('network', 14),
#  ('token', 12),
#  ('crypto', 12)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
bitcoin_wc = WordCloud().generate(' '.join(bitcoin_df.tokens.sum()))
plt.label = 'Bitcoin Word Cloud'
plt.imshow(bitcoin_wc)

# %%
# Generate the Ethereum word cloud
ethereum_wc = WordCloud().generate(' '.join(ethereum_df.tokens.sum()))
plt.imshow(ethereum_wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_texts = ' '.join(bitcoin_df.text.to_list())
bitcoin_texts
# Out:
# 'FTX, a cryptocurrency exchange that offers derivatives, options and other sophisticated products, is acquiring a popular portfolio tracking app, Blockfolio.\r\nFTX is spending $150 million for the acqu… [+1325 chars] Isolation.site does just one thing: it visits URLs that you want to check out but don\'t trust, and shows you what comes up. It\'s not just a convenient wrapper around the curl command-line tool, but g… [+1726 chars] An outspoken Bitcoin whale who rarely shows affection for anything other than BTC says two crypto assets have potential.\r\nThe pseudonymous trader known as Joe007 says UNUS SED LEO (LEO) may be a soli… [+1503 chars] ...The canton, which bills itself as home to "Crypto Valley," said it would accept taxes from companies or individuals of up to 100,000 Swiss francs (about $110,000) paid in Bitcoin or Ether as of Fe… [+242 chars] Gold and oil have historically been reliable stores of value. Because they are scarce commodities, they make dependable hedges to the inflation of fiat currencies. As a result, they have commanded pr… [+25030 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2801 chars] In video meetings it\'s a hassle to unmute just to say one word especially if someone else is speaking. I created a video lens that uses hand gestures to show comic-book style messages instead. So far… [+3170 chars] Jeff Royder, Sr. Acct Mgr, is the Michael Scott character in this funny short and too-real series called Join Meeting about a group of employees having Zoom meetings. There are five episodes so far, … [+1547 chars] FILE PHOTO: A man types on a computer keyboard in this illustration picture February 28, 2013. REUTERS/Kacper Pempel/Illustration/File Photo/File Photo - Kacper Pempel/REUTERS\r\nProsecutors in Germany… [+3522 chars] Woad is a plant and a blue dye taken thereof, popularly associated with iron-age Britons but replaced by the superior Indigo plant long before the modern age. But it has its fans and now you can even… [+2507 chars] ALMATY, Sept 2 (Reuters) - Kazakhstan is in talks to attract investments worth 300 billion tenge ($714 million) into the cryptocurrency sector, Digital Development Minister Bagdat Mussin said on Wedn… [+825 chars] For at least a year, hackers have been passing around and trying to break into a Bitcoin wallet that potentially holds around $690 million, or 69,370 BTC. This would be the wallet with the seventh hi… [+3849 chars] Stimulus checks helped millions of Americans make ends meet earlier this year, however Democrats and Republicans have struggled to agree on terms for a second stimulus checkand there may not be one a… [+2954 chars] NEW YORK CITY, NY, UNITED STATES - 2020/02/17: A view of an american multinational financial ... [+] services corporation Fidelity Investments logo. (Photo by Alex Tai/SOPA Images/LightRocket via Get… [+2653 chars] By Reuters Staff\r\nFILE PHOTO: Silhouette of mobile device user is seen next to a screen projection of binary code are seen in this picture illustration taken March 28, 2018. REUTERS/Dado Ruvic/Illust… [+1121 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2968 chars] Last month, I showed how Bitcoin broke above its key $10,000 to $11,000 resistance zone, which was a sign of technical strength. Since then, Bitcoin has held onto its gains, but has been consolidatin… [+1031 chars] (Reuters) - The U.S. government sought on Thursday to seize 280 cryptocurrency accounts it said were used by North Korean hackers who stole millions of dollars of cryptocurrency from two virtual exch… [+1737 chars] My kids love laptops. They especially love laptops that play Minecraft and let them watch YouTube for hours at a ti ...

# %%
# Run the NER processor on all of the text
bitcoin_nlp = nlp(bitcoin_texts)

# Add a title to the document
bitcoin_nlp.user_data['title'] = 'Bitcoin NER'

# %%
# Render the visualization
displacy.render(bitcoin_nlp, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FTX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a cryptocurrency exchange that offers derivatives, options and other sophisticated products, is acquiring a popular portfolio tracking app,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blockfolio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FTX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is spending
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $150 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for the acqu… [+1325 chars] Isolation.site does
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  thing: it visits URLs that you want to check out but don't trust, and shows you what comes up. It's not just a convenient wrapper around the curl command-line tool, but g… [+1726 chars] An outspoken
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  whale who rarely shows affection for anything other than
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The pseudonymous trader known as Joe007 says
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNUS SED LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) may be a soli… [+1503 chars] ...The canton, which bills itself as home to &quot;
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto Valley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,&quot; said it would accept taxes from companies or individuals of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to 100,000 Swiss francs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $110,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) paid in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ether
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+242 chars] Gold and oil have historically been reliable stores of value. Because they are scarce commodities, they make dependable hedges to the inflation of fiat currencies. As a result, they have commanded pr… [+25030 chars] Our robot colleague
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-t

# %%
# List all Entities
for entity in list(set(bitcoin_nlp.ents)):
    print(f'{entity.text} {entity.label_}')
# Out:
# 100,000 MONEY
# Depa PERSON
# five years ago DATE
# Reuters ORG
# Fidelity Investments ORG
# US GPE
# Bitcoin GPE
# LONDON GPE
# NEW YORK CITY GPE
# Abolaji Odunjo ORG
# Satoshi Nakaboto PERSON
# March DATE
# Bitcoin GPE
# Get Forbes' PERSON
# Bitcoin GPE
# Bitcoin GPE
# Alexis Akwagyiram PERSON
# 10,000 MONEY
# the end of July DATE
# REUTERS/Kacper Pempel/Illustration/File Photo/File Photo - Kacper Pempel/ ORG
# Bitcoin GPE
# Ether PERSON
# Satoshi Nakaboto PERSON
# Nvidia ORG
# Qali WORK_OF_ART
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Russian NORP
# Satoshi Nakaboto ORG
# about $110,000 MONEY
# Thursday DATE
# seventh ORDINAL
# $150 million MONEY
# four CARDINAL
# Uber PERSON
# one CARDINAL
# Today DATE
# $40 billion MONEY
# Ryuk ORG
# two CARDINAL
# two CARDINAL
# US GPE
# Reuters ORG
# a year DATE
# Bitcoin GPE
# the United States District Court GPE
# Sjoerd Knibbeler PERSON
# just ten years DATE
# one CARDINAL
# Reuters ORG
# two years DATE
# LAGOS/LONDON ORG
# March 28, 2018 DATE
# Bitcoin GPE
# UNUS SED LEO ORG
# Bitcoin GPE
# bitcoin GPE
# UK GPE
# REUTERS/Dado Ruvic/Illust ORG
# Tom Wilson PERSON
# the Delta Summit EVENT
# Bitcoin GPE
# $100 million MONEY
# Bitcoin GPE
# at least a year DATE
# about 20% PERCENT
# Deloitte ORG
# three CARDINAL
# ETH ORG
# French NORP
# Julija PERSON
# Market Rasen PERSON
# July DATE
# LAGOS/LONDON ORG
# Massachusetts GPE
# Bitcoin GPE
# 69,370 CARDINAL
# Blockfolio GPE
# Indian NORP
# Bitcoin GPE
# Reuters ORG
# Narendra Modis PERSON
# July DATE
# Germany GPE
# bitcoin GPE
# Bitcoin GPE
# Elon Musk ORG
# Russian NORP
# 6 min QUANTITY
# U.S. GPE
# £22.5 million MONEY
# Today DATE
# 18 DATE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# five CARDINAL
# Pour GPE
# Bitcoin GPE
# 2016 DATE
# Joseph Sullivan PERSON
# one CARDINAL
# bitcoin GPE
# two CARDINAL
# Indians NORP
# Bitcoin GPE
# Lagos GPE
# millions CARDINAL
# BTC ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Reuters ORG
# Bitcoin GPE
# $100 milli MONEY
# Donald Trump PERSON
# Bitcoin GPE
# Angela Lang PERSON
# Satoshi Nakaboto ORG
# Satoshi Nakaboto PERSON
# 17-year-old DATE
# Bitcoin GPE
# Indigo ORG
# Today DATE
# FTX ORG
# Bitcoin GPE
# South Africa GPE
# $61 million MONEY
# Satoshi Nakaboto PERSON
# a footing over $12,000 MONEY
# Today DATE
# Kenya GPE
# Lincolnshire GPE
# Bitcoin GPE
# 280 CARDINAL
# around $690 million MONEY
# Jeff Royder PERSON
# The weekend DATE
# 29.46 MONEY
# Ethereum ORG
# Reuters ORG
# Bitcoin GPE
# Arm Limited PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Today DATE
# March DATE
# Bitcoin GPE
# Thailand GPE
# Thursday DATE
# 365,000 Singapore dollars MONEY
# The Department of Justice ORG
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto ORG
# Reuters ORG
# three CARDINAL
# Bitcoin GPE
# Republicans NORP
# Zoom PERSON
# John Wick PERSON
# Americans NORP
# recent weeks DATE
# second ORDINAL
# Satoshi Nakaboto ORG
# 1,000 MONEY
# earlier this year DATE
# Every week DATE
# Monthly DATE
# Bitcoin GPE
# Wednesday DATE
# Pardon The Intrusion ORG
# Satoshi Nakaboto ORG
# Today DATE
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Satoshi Nakaboto PERSON
# US GPE
# Thursday DATE
# 16-year-old DATE
# this year DATE
# Two CARDINAL
# $714 million MONEY
# Satoshi Nakaboto PERSON
# Satoshi Nakaboto PERSON
# U.S. GPE
# Reuters ORG
# TNWs bi-weekly PERSON
# 2020 DATE
# Today DATE
# Reuters ORG
# Bitcoin GPE
# Reuters ORG
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# WASHINGTON GPE
# Bitcoin GPE
# millions of dollars MONEY
# Uber PRODUCT
# Bitcoin GPE
# 2018 DATE
# Satoshi Nakaboto ORG
# March DATE
# Today DATE
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Julija Adlesic PERSON
# Satoshi Nakaboto ORG
# the past few years DATE
# Sept 2 DATE
# 52-year-old DATE
# Ta' GPE
# 280 CARDINAL
# Bitcoin GPE
# U.S. GPE
# Bitcoin GPE
# Bitcoin GPE
# The Correspondent WORK_OF_ART
# Crypto Valley LOC
# Bitcoin GPE
# one CARDINAL
# Sullivan PERSON
# 5% PERCENT
# two CARDINAL
# Bitcoin GPE
# Today DATE
# U.S. GPE
# Bitcoin GPE
# Satoshi Nakaboto ORG
# February 28, 2013 DATE
# Sept. 7 DATE
# Satoshi Nakaboto PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Tesla Nevada FAC
# Empire Market ORG
# Twitter ORG
# Bitcoin GPE
# Graham Clark PERSON
# up to eight years DATE
# 24-hour TIME
# Tesco ORG
# Tesla ORDINAL
# Today DATE
# Bitcoin GPE
# Wedn PERSON
# up to 100,000 Swiss francs MONEY
# Abolaji Odunjo ORG
# this week DATE
# Bitcoin GPE
# Singapore GPE
# Today DATE
# Minecraft PERSON
# July DATE
# Bitcoin GPE
# Bitcoin GPE
# Bitcoin GPE
# Democrats NORP
# Slovenian NORP
# Satoshi Nakaboto ORG
# Satoshi Nakaboto ORG
# about 57 mi CARDINAL
# Thursday DATE
# Satoshi Nakaboto PERSON
# Alex Tai PERSON
# Today DATE
# recent months DATE
# Satoshi Nakaboto ORG
# american NORP
# bitcoin GPE
# Sunday evening TIME
# Twitter ORG
# Russian NORP
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Twitter ORG
# The Complete Stock and Cryptocurrency Investment Toolkit Bundle ORG
# September DATE
# UNITED STATES GPE
# Satoshi Nakaboto ORG
# the wee hours of the morning TIME
# bitcoin GPE
# Bitcoin GPE
# Thursday DATE
# Uber Technologies ORG
# North Korean NORP
# Reuters ORG
# Satoshi Nakaboto ORG
# Satoshi Nakaboto ORG
# FTX ORG
# Sky News ORG
# Binance ORG
# the past few years DATE
# second ORDINAL
# Sept 10 DATE
# Uber PERSON
# bitcoin GPE
# Bitcoin GPE
# Bitcoin GPE
# Bitcoin GPE
# Elon Musk ORG
# Bitcoin GPE
# Bryan Connor Herrell PERSON
# Today DATE
# 55% PERCENT
# Michael Scott PERSON
# Bitcoin GPE
# 10,000 MONEY
# just one CARDINAL
# Bitcoin GPE
# India GPE
# Thursday DATE
# Acct Mgr PERSON
# Bitcoin GPE
# KPMG ORG
# Bitcoin GPE
# Winklevoss PERSON
# Digital Development ORG
# Joe Sullivan PERSON
# Last month DATE
# Today DATE
# Bitcoin GPE
# Bitcoin GPE
# Bitcoin GPE
# Africa LOC
# nine zeros CARDINAL
# the Northern District LOC
# two CARDINAL
# SoftBank ORG
# Bitcoin GPE
# 2013-2016 DATE
# Bitcoin GPE
# 97% PERCENT
# Satoshi Nakaboto ORG
# millions of dollars MONEY
# NY ORG
# Four months ago DATE
# Gove WORK_OF_ART
# Digital Innovation ORG
# Today DATE
# Activision PRODUCT
# VPN PRODUCT
# years DATE
# Satoshi Nakaboto PERSON
# Fidelity ORG
# Bagdat Mussin PERSON
# Bitcoin GPE
# Join Meeting ORG
# 4,000 MONEY
# an estimated $30 million MONEY
# Satoshi Nakaboto PERSON
# BTC ORG
# Nigel Wright PERSON
# the last few months DATE
# Bitcoin GPE
# Today DATE
# under 24 hours TIME
# Blockchain ORG
# 300 billion tenge MONEY
# Reuters ORG
# Bitcoin GPE
# 11 years DATE
# North Korean NORP
# Bitcoin GPE
# 11,000 MONEY
# Satoshi Nakaboto PERSON
# American NORP
# Satoshi Nakaboto PERSON
# LEO ORG
# August DATE
# Bitcoin GPE
# Bitcoin GPE
# Get Forbes' PERSON
# Nigeria GPE
# Today DATE
# YouTube for hours TIME
# Satoshi Nakaboto PERSON
# Malta GPE
# more than 10% PERCENT
# Today DATE
# two CARDINAL
# Fe ORG
# 'Current Studies' WORK_OF_ART
# Bitcoin GPE
# Four months ago DATE
# Lagos GPE
# the Federal Reserve's ORG

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_texts = ' '.join(ethereum_df.text.to_list())
ethereum_texts
# Out:
# 'An Ethereum smart contract feature that offers rebates for fees has developers scratching their heads, wondering if they should toss the old code in light of an exponential rise in transaction costs.… [+3503 chars] Swisscom Blockchain, a distributed ledger technology startup owned by telco giant Swisscom, has been awarded a grant from the Web3 Foundation to build a cloud-based protection layer for stakers on th… [+2550 chars] The native token for OMG Network has more than doubled in the past week as record Ethereum fees lead some investors to look to layer-2 solutions.\r\n<ul><li>CoinGecko data shows OMG tokens have increas… [+1681 chars] The Takeaway\r\n<ul><li>Under development by the LNP/BP Standards Association, the RGB protocol entered beta in June.</li><li>The second layer network promises to bring smart contracts and tokenized as… [+7463 chars] Uniswaps governance token, UNI, which was launched Wednesday night, has been on a roller-coaster ride in the past 24 hours, but despite the price volatility the total market cap of UNI could make the… [+2870 chars] An outspoken Bitcoin whale who rarely shows affection for anything other than BTC says two crypto assets have potential.\r\nThe pseudonymous trader known as Joe007 says UNUS SED LEO (LEO) may be a soli… [+1503 chars] After the Medalla testnet went live last month, Ethereum will be getting one more dress rehearsal before the eventual launch of its next iteration, Ethereum 2.0.\r\nIn a Monday blog post, ETH 2.0 devel… [+1214 chars] A critical bug has left 13% of Ethereum nodes useless, highlighting what is a growing chink in the networks armor: client centralization.\r\nFirst hinted at in May and June on GitHub, minority clients … [+3154 chars] The Securities and Exchange Commission announced a settlement with esports-betting cryptocurrency firm Unikrn for alleged violations of securities laws. Unikrn will shutter its UnikoinGold cryptocurr… [+5630 chars] A "hack-proof" smart padlock with security based on blockchain technology could be defeated by a simple Bluetooth replay attack or a 1kg lump hammer.\r\nThe 360lock, a technologically enabled padlock (… [+2075 chars] EOS\r\nEOS slid by 2.05% on Monday. Following on from a 1.16% loss on Sunday, EOS ended the day at $2.8437.\r\nIt was a mixed start to the day. EOS rose to an early morning intraday high $2.9416 before h… [+5041 chars] Life Belt with Bitcoin Money Sack on Wood Floor - Chalkboard Background - 3D Rendering\r\ngetty\r\nLast week, bitcoin experienced the largest weekly decline since March, initiated by sudden strength in t… [+3184 chars] INX is gearing up for a landmark IPO, 1 billion tether jumped from Tron to Ethereum and a shift in bitcoin’s options market suggests bullish speculation is beginning to ease.\r\nYoure reading\xa0Blockchai… [+7081 chars] Decentralized finance (DeFi) credit market Aave has pulled ahead of stablecoin mint MakerDAO for the title of most collateral staked on Ethereum, according to DeFi Pulse.\r\nAave now has $1.47 billion-… [+2825 chars] The price of Bitcoin looks to enter a new range after a key breakout.\r\nSOPA Images/LightRocket via Getty Images\r\nThe price of Bitcoin rose to as high as $12,086 on Coinbase, as Ethereum (ETH) buoyed … [+3138 chars] NEW YORK (Reuters) - Brooklyn-based technology startup ConsenSys has acquired JPMorgan Chase &amp; Co’s (JPM.N) marquee blockchain platform Quorum, the companies said on Tuesday. \r\nAs part of the dea… [+1915 chars] The Ethereum Classic blockchain suffered a 51% attack Saturday evening, its third 51% attack this month, noticed by mining company Bitfly, which also spotted the first attack on Aug. 1.\r\n<ul><li>The … [+2116 chars] Bitcoin lost momentum Thursday while DeFi delirium pushes fees on Ethereum back up.\r\n<ul><li>Bitcoin (BTC) trading around $10,920 as of 20:00 UTC (4 p.m. ET). Slipping 0.73% over the previous 24 hour… [+4031 chars] Mongolian authorities have put the kibosh on cheap electricity for crypto miners, Venezuela  ...

# %%
# Run the NER processor on all of the text
ethereum_nlp = nlp(ethereum_texts)

# Add a title to the document
ethereum_nlp.user_data['title'] = 'Ethereum NER'

# %%
# Render the visualization
displacy.render(ethereum_nlp, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">An Ethereum smart contract feature that offers rebates for fees has developers scratching their heads, wondering if they should toss the old code in light of an exponential rise in transaction costs.… [+3503 chars] Swisscom Blockchain, a distributed ledger technology startup owned by telco giant
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Swisscom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , has been awarded a grant from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Web3 Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to build a cloud-based protection layer for stakers on th… [+2550 chars] The native token for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OMG Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has more than doubled in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>&lt;ul&gt;&lt;li&gt;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CoinGecko
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  data shows OMG tokens have increas… [+1681 chars] The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Takeaway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>&lt;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ul&gt;&lt;li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# &gt;Under development by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the LNP/BP Standards Association
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RGB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  protocol entered beta in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June.&lt;/li&gt;&lt;li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &gt;The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  layer network promises to bring smart contracts and tokenized as… [+7463 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uniswaps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  governance token,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which was launched
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , has been on a roller-coaster ride in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past 24 hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , but despite the price volatility the total market cap of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  could make the… [+2870 chars] An outspoken
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  whale who rarely shows affection for anything other than
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The pseudonymous trader known as Joe007 says
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNUS SED LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; te

# %%
# List all Entities
for entity in list(set(ethereum_nlp.ents)):
    print(f'{entity.text} {entity.label_}')
# Out:
# Uniswaps ORG
# three weeks DATE
# the past few months DATE
# two CARDINAL
# Tuesday DATE
# 6 min QUANTITY
# 18 DATE
# Thursday DATE
# 3.1234 MONEY
# the Web3 Foundation ORG
# Monday DATE
# LEO ORG
# LTC ORG
# INX Ltd. ORG
# BTC ORG
# 0.73% PERCENT
# the past 24 hours TIME
# NEW YORK GPE
# first ORDINAL
# BTC ORG
# Medalla PERSON
# ul><li PERSON
# Sunday DATE
# Liz Steininger PERSON
# 4 p.m. ET TIME
# Ethereum 2.0 ORG
# 4.8% PERCENT
# developer house Snowfork ORG
# DeFi ORG
# Ethereum Classics ORG
# Ethereum 2.0 ORG
# September 1 DATE
# Reuters ORG
# Russian NORP
# DeFi PERSON
# zero CARDINAL
# ul><li PERSON
# 3.8% PERCENT
# Ethereum 2.0 ORG
# AI GPE
# ETH ORG
# DeFi LOC
# DeFi PERSON
# 6 min QUANTITY
# Blockchai GPE
# this month DATE
# Fall 2020 DATE
# the Ethereum Foundation ORG
# less than 1,200 CARDINAL
# INX ORG
# years DATE
# today DATE
# Polkadot ORG
# BTC ORG
# Bitcoin GPE
# First ORDINAL
# May and June DATE
# Arbol ORG
# nearly $17 million MONEY
# ConsenSys ORG
# BTC ORG
# Wednesday DATE
# Ethereum ( ORG
# 1.47 MONEY
# Fidelity ORG
# Tether PERSON
# Bloomberg News ORG
# first ORDINAL
# Kraken ORG
# one CARDINAL
# CryptoKitties ORG
# Chainlink ORG
# Kava Labs PERSON
# Thursday DATE
# today DATE
# AMD ORG
# 13% PERCENT
# last week DATE
# UNI ORG
# The Complete Stock and Cryptocurrency Investment Toolkit Bundle ORG
# the past week DATE
# DeFi PERSON
# recent weeks DATE
# Bitcoin GPE
# the Interactive Learn LOC
# Last week DATE
# another 51% PERCENT
# around $10,669 MONEY
# Today DATE
# Thursday DATE
# JPMorgan ORG
# Vijay Michalik PERSON
# 20:00 TIME
# Coinbase PRODUCT
# Asia LOC
# around $10,920 MONEY
# Mongolian NORP
# Ethereum Classic ORG
# Brooklyn GPE
# 20:00 TIME
# RGB ORG
# 2020 DATE
# DeFi ORG
# Deloitte ORG
# the past month DATE
# Bitcoin GPE
# Berlin GPE
# KPMG ORG
# September DATE
# China GPE
# Brooklyn GPE
# Emfarsis ORG
# the day DATE
# the day DATE
# 1.99% PERCENT
# Monday DATE
# CoinDesk Research ORG
# 4 p.m. ET TIME
# 4 p.m. ET TIME
# Bitcoin GPE
# Arbol ORG
# this week DATE
# 4 p.m. ET TIME
# 13% PERCENT
# weeks DATE
# Monday DATE
# ul><li PERSON
# the previous 24 DATE
# next Monday DATE
# weekly DATE
# 2.05% PERCENT
# 8% PERCENT
# Quorum PRODUCT
# Bitcoin GPE
# CoinGecko ORG
# Ethereum 2.0 ORG
# first ORDINAL
# three 51% PERCENT
# the Financial Industry Regulatory Authority ORG
# 0.42% PERCENT
# a month DATE
# DeFi Pulse PERSON
# Ethereum ORG
# 51% PERCENT
# TRON ORG
# un ORG
# $100 milli MONEY
# 7.77% PERCENT
# EY GPE
# digital cryptocurrency exchange ORG
# ul><li PERSON
# Tether PERSON
# Microsoft ORG
# Bitcoin GPE
# Bitcoin GPE
# Protocol LAW
# more than 10% PERCENT
# Wednesday DATE
# 3.3961 MONEY
# second ORDINAL
# Out of the Ether: WORK_OF_ART
# Ethereum ORG
# last month DATE
# Danny Ryan PERSON
# 2.9416 MONEY
# Reuters ORG
# Tether PERSON
# Ethereum Classic ORG
# Ethereum ORG
# before our regular noon TIME
# Digital ORG
# The Block Research ORG
# Mongolian NORP
# 1 billion USDT MONEY
# BTC-USD ORG
# 1 billion CARDINAL
# Micr PERSON
# Tron to Ethereum ORG
# bitcoin GPE
# Takeaway ORG
# 51% PERCENT
# Wednesday night TIME
# Aug. 1 DATE
# ConsenSys ORG
# Ethereum 2.0 ORG
# UNI ORG
# 16 DATE
# Satoshi Nakaboto ORG
# Venezuela GPE
# ul><li PERSON
# Stefan George of Gnosis PERSON
# The Securities and Exchange Commission ORG
# DeFi ORG
# two CARDINAL
# Avalanche ORG
# third ORDINAL
# U.S. GPE
# Over $1 billion MONEY
# the LNP/BP Standards Association ORG
# Swisscom ORG
# the two weeks DATE
# 20:00 TIME
# CoinDesk Research ORG
# LONDON GPE
# five years ago DATE
# Uniswap ORG
# second ORDINAL
# one CARDINAL
# as many as 15 CARDINAL
# GitHub ORG
# Ethereum, CoinDesks Markets Daily ORG
# the previous 24 hours TIME
# Bitcoin GPE
# ConsenSys ORG
# AR ORG
# Ethereum Classic ORG
# DEFI ORG
# 92,600 CARDINAL
# Ethereum ORG
# DeFi ORG
# just above $10,000 MONEY
# ETH ORG
# the Ethereum 2.0 ORG
# 30% PERCENT
# Bitfly ORG
# September DATE
# JPMorgan Chase &amp ORG
# Oasis Labs ORG
# today DATE
# OCC ORG
# 51% PERCENT
# Mathew Leising PERSON
# the past week DATE
# U.S. GPE
# more than 100% PERCENT
# UNUS SED LEO ORG
# BTC ORG
# 13% PERCENT
# March DATE
# Tether PERSON
# 2017 DATE
# Today DATE
# around $11,298 MONEY
# Ava Labs PERSON
# Indians NORP
# One dollar MONEY
# India GPE
# 2017 DATE
# 20:00 TIME
# BTC ORG
# Uniswap ORG
# BTC ORG
# early morning TIME
# 10,000 CARDINAL
# 2.8437 MONEY
# 1kg QUANTITY
# #2 digital dollar MONEY
# DeFi LOC
# June.</li><li GPE
# a record $16 million MONEY
# Galaxy Digital PERSON
# more than 350 CARDINAL
# Wednesday DATE
# USDT ORG
# 51% PERCENT
# Bitcoin GPE
# Thursday DATE
# the previous 24 hour TIME
# Tuesday DATE
# IOSG Ventures ORG
# bitcoin GPE
# March DATE
# the day DATE
# January DATE
# Bitcoin GPE
# $1.2 million MONEY
# more than $1 billion MONEY
# August DATE
# 3.4% PERCENT
# UNI ORG
# about 20% PERCENT
# ETH-USD ORG
# September DATE
# 400 CARDINAL
# Paolo Ardoino PERSON
# bitcoin GPE
# CryptoSafe Alliance ORG
# Venezuela GPE
# RenVM DeFi LOC
# as high as $12,086 MONEY
# Ethereum (ETH ORG
# Tuesday DATE
# ul><li PERSON
# CoinDesks Markets Daily ORG
# Christine Kim PERSON
# Algorand ORG
# UnikoinGold ORG
# 5-10% PERCENT
# FINRA ORG
# Bitcoin GPE
# UNI ORG
# U.S. GPE
# today DATE
# Harvest ORG
# DeFi ORG
# Polkadot ORG
# Quorum PRODUCT
# recent weeks DATE
# Saturday DATE
# above $11 MONEY
# twenty dollars MONEY
# January DATE
# 29.46 MONEY
# US GPE
# Tuesday DATE
# evening TIME
# 24-hour TIME
# DeFi ORG
# Crypto PERSON
# Mateusz Slodkowski/ PERSON
# bitcoin GPE
# the early 1980s DATE
# around $11,396 MONEY
# one CARDINAL
# Baseline Protocol PRODUCT
# 1.16% PERCENT
# working dynamics ORG
# OMG Network ORG
# around 00:30 TIME
# ul><li PERSON
# European NORP
# Sept. 7 DATE
# $55 Million MONEY
# BTC ORG
# 2020 DATE
# Ben Edgington PERSON
# $1 billion MONEY
# Bitcoin GPE
# 97% PERCENT
# Bitcoin GPE
# $100 million MONEY
# BTC ORG
# last month DATE
# early morning TIME
# Christine Kim PERSON
# May DATE
# JPMorgan Chase ORG
# RenVM GPE
# ul><li PERSON
# dozens CARDINAL
# Thursday DATE
# DeFi LOC
# Satoshi Nakaboto PERSON
# ETH ORG
# the past couple of years DATE
# Leah Callon-Butler PERSON
# bitcoin GPE
# Unikrn ORG
# Signature Bank ORG
# the day DATE
# Bitcoin GPE
# Bitcoin GPE
# the U.S. Office of the Comptroller of the Currency ORG
# Unikrn ORG
# Bitcoin Money Sack on Wood Floor - Chalkboard Background - 3D ORG
# two CARDINAL
# Ethereum Classics ORG
# Monday DATE
# second ORDINAL
# second ORDINAL
# Danny Ryan PERSON
# Ethereum Classic PRODUCT
