# %% [markdown]
# # San Francisco Rental Prices Dashboard
#
# In this notebook, you will compile the visualizations from the previous analysis into functions that can be used for a Panel dashboard.

# %%
# initial imports
import os
import plotly
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import panel as pn
import plotly.express as px
from pathlib import Path
from dotenv import load_dotenv

# # Initialize the Panel Extensions (for Plotly)
pn.extension('plotly')
# Out:
# WARNING:param.panel_extension: A HoloViz extension was loaded previously. This means the extension is already initialized and the following Panel extensions could not be properly loaded: ['plotly']. If you are loading custom extensions with pn.extension(...) ensure that this is called before any other HoloViz extension such as hvPlot or HoloViews.

# %%
# Read the Mapbox API key
load_dotenv()
mapbox_token = os.getenv('MAPBOX_API_KEY')

# %% [markdown]
# # Import Data

# %%
# Import the CSVs to Pandas DataFrames
file_path = Path("Data/sfo_neighborhoods_census_data.csv")
sfo_data = pd.read_csv(file_path, index_col="year")
sfo_data['neighborhood'] = sfo_data['neighborhood'].str.strip()
sfo_data.rename(columns = {'neighborhood': 'Neighborhood'}, inplace=True)

file_path = Path("Data/neighborhoods_coordinates.csv")
df_neighborhood_locations = pd.read_csv(file_path)

# %% [markdown]
# - - -

# %% [markdown]
# ## Panel Visualizations
#
# In this section, you will copy the code for each plot type from your analysis notebook and place it into separate functions that Panel can use to create panes for the dashboard.
#
# These functions will convert the plot object to a Panel pane.
#
# Be sure to include any DataFrame transformation/manipulation code required along with the plotting code.
#
# Return a Panel pane object from each function that can be used to build the dashboard.
#
# Note: Remove any `.show()` lines from the code. We want to return the plots instead of showing them. The Panel dashboard will then display the plots.

# %%
# Define Panel Visualization Functions
def housing_units_per_year():
    """Housing Units Per Year."""
    buffer = .01
    sfo_average_units = sfo_data.groupby(sfo_data.index).mean()["housing_units"]
    return px.bar(
        sfo_average_units,
        title = f'Housing Units in San Francisco from {sfo_data.index.min()} to {sfo_data.index.max()}',
    ).update_layout(yaxis=dict(range=[sfo_average_units.min()*(1-buffer), sfo_average_units.max()*(1+buffer)]))

def average_gross_rent():
    """Average Gross Rent in San Francisco Per Year."""
    sfo_average_rent = sfo_data.groupby(sfo_data.index).mean()["gross_rent"]
    return px.line(
        sfo_average_rent,
        title = "Average Sale Price per Square Foot in San Francisco"
    )


def average_sales_price():
    """Average Sales Price Per Year."""
    sfo_average_sqrt_ft_price = sfo_data.groupby(sfo_data.index).mean()["sale_price_sqr_foot"]
    return px.line(
        sfo_average_sqrt_ft_price,
        title = "Average Gross Rent in San Francisco"
    )


def average_price_by_neighborhood():
    """Average Prices by Neighborhood."""
    sfo_average_data = sfo_data.groupby(['year', 'Neighborhood']).mean().reset_index()
    
    import panel as pn
    from panel.interact import interact
    pn.extension()

    def average_plot(neighborhood):
        average_price = sfo_average_data.loc[sfo_average_data['Neighborhood'] == neighborhood].hvplot.line(
            x = 'year',
            xlabel = 'Year',
            y = 'sale_price_sqr_foot',
            ylabel = 'Sale Price Square Foot (USD)',
            title = 'Average Prices by Neighborhood'
        )
        return average_price

    return interact(average_plot, neighborhood=sorted(list(dict.fromkeys(list(sfo_average_data['Neighborhood'])))))


def top_most_expensive_neighborhoods():
    """Top 10 Most Expensive Neighborhoods."""
    top_10_expensive_neighborhood = sfo_data.groupby(['Neighborhood']).mean().sort_values('sale_price_sqr_foot', ascending=False).head(10)
    
    return px.bar(
        top_10_expensive_neighborhood['sale_price_sqr_foot']
    )


def parallel_coordinates():
    """Parallel Coordinates Plot."""
    top_10_expensive_neighborhood = sfo_data.groupby(['Neighborhood']).mean().sort_values('sale_price_sqr_foot', ascending=False).head(10)
    
    return px.parallel_coordinates(
        top_10_expensive_neighborhood,
        color = "sale_price_sqr_foot"
    )

def parallel_categories():
    """Parallel Categories Plot."""
    top_10_expensive_neighborhood = sfo_data.groupby(['Neighborhood']).mean().sort_values('sale_price_sqr_foot', ascending=False).head(10)
    
    return px.parallel_categories(
        top_10_expensive_neighborhood.reset_index(),
        color = 'sale_price_sqr_foot',
        color_continuous_scale = px.colors.sequential.Inferno,
    )


def neighborhood_map():
    """Neighborhood Map"""
    # Load neighborhood coordinates
    file_path = Path("Data/neighborhoods_coordinates.csv")
    df_neighborhood_locations = pd.read_csv(file_path)
    
    # Group data by neighborhood
    neighborhood_average = sfo_data.groupby(['Neighborhood']).mean().reset_index()
    
    # Join neighborhood data with coordinates
    joined_data = df_neighborhood_locations.set_index('Neighborhood').join(neighborhood_average.set_index('Neighborhood')).reset_index()
    
    px.set_mapbox_access_token(mapbox_token)
    
    return px.scatter_mapbox(
        joined_data,
        title = 'Average Sale Price per Square Foot and Gross Rent in San Francisco',
        lat = 'Lat',
        lon = 'Lon',
        text = 'Neighborhood',
        size = 'sale_price_sqr_foot',
        color = 'gross_rent',
        color_continuous_scale = px.colors.sequential.Rainbow,
        zoom = 10
    )

# %% [markdown]
# ## Panel Dashboard
#
# In this section, you will combine all of the plots into a single dashboard view using Panel. Be creative with your dashboard design!

# %%
welcome_column = pn.Column(
    '##### This dashboard presents a visual analysis of historical prices of house units, sale price per square foot and gross rent in San Francisco, California from 2010 to 2016.  You can navigate through the tabs above to explore more details about the evolution of the real estate market on The Golden City across these years.',
    neighborhood_map()
)

yearly_column = pn.Row(
    housing_units_per_year(),
    average_gross_rent(),
    average_sales_price()
)

neighborhood_column = pn.Column(
    average_price_by_neighborhood(),
    top_most_expensive_neighborhoods()
)

parallel_column = pn.Column(
    parallel_coordinates(),
    parallel_categories()
)

tabs = pn.Tabs(
    ('Welcome', welcome_column),
    ('Yearly Market Analysis', yearly_column),
    ('Neighborhood Analysis', neighborhood_column),
    ('Parallel Plots Analysis', parallel_column)
)
tabs
# Out:
# Tabs
#     [0] Column
#         [0] Markdown(str)
#         [1] Plotly(Figure)
#     [1] Row
#         [0] Plotly(Figure)
#         [1] Plotly(Figure)
#         [2] Plotly(Figure)
#     [2] Column
#         [0] Column
#             [0] Column
#                 [0] Select(name='neighborhood', options=['Alamo Square', ...], value='Alamo Square')
#             [1] Row
#                 [0] HoloViews(Curve, name='interactive01464')
#         [1] Plotly(Figure)
#     [3] Column
#         [0] Plotly(Figure)
#         [1] Plotly(Figure)

# %% [markdown]
# ## Serve the Panel Dashboard

# %%
tabs.servable()
# Out:
# Tabs(active=3)
#     [0] Column
#         [0] Markdown(str)
#         [1] Plotly(Figure)
#     [1] Row
#         [0] Plotly(Figure, viewport={'xaxis.range': [2009.5, ...})
#         [1] Plotly(Figure, viewport={'xaxis.range': [2010, ...})
#         [2] Plotly(Figure, viewport={'xaxis.range': [2010, ...})
#     [2] Column
#         [0] Column
#             [0] Column
#                 [0] Select(name='neighborhood', options=['Alamo Square', ...], value='Alamo Square')
#             [1] Row
#                 [0] HoloViews(Curve, name='interactive01464')
#         [1] Plotly(Figure, viewport={'xaxis.range': [-0.5, ...})
#     [3] Column
#         [0] Plotly(Figure)
#         [1] Plotly(Figure)
